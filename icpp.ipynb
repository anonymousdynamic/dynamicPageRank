# %%
pip install seaborn

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"

plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(5,2,figsize=[10, 10])
fig.subplots_adjust(hspace=0.725, wspace=0.185)
sns.set_style('whitegrid')


data=pd.read_csv("scIA3gpucomparison.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]
dataselected

ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g1=sns.barplot(data=dataselected, x="changes",ax=ax[0][0],hue="method", y="time",palette="colorblind")

g1.legend('',frameon=False)
for bar in g1.patches:


    g1.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
# ax[0][0].set_xticks(['50K','100K'])
ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set(ylabel=None)
ax[0][0].set(xlabel=None)
ax[0][0].set(xticklabels=[])


dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected



g2=sns.barplot(data=dataselected, x="changes",ax=ax[0][1],hue="method", y="time",palette="colorblind")

g2.legend('',frameon=False)


ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

# ax[0][1].set_xticks(['50K','100K'])

for bar in g2.patches:

    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set(ylabel=None)
ax[0][1].set(xlabel=None)



dataselected= data[data["graphName"]=="PubMed"]
dataselected

ax[0][1].set(xticklabels=[])  # remove the tick labels
ax[0][1].tick_params(bottom=False)
for bar in g2.patches:

    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
ax[1][0].yaxis.label.set_size(20)
ax[1][0].set_title('PubMed', fontname="Times New Roman", size=8,fontweight="bold",pad=10)
g3=sns.barplot(data=dataselected, x="changes",ax=ax[1][0],hue="method", y="time",palette="colorblind")

g3.legend('',frameon=False)


# ax[1][0].set_xticks(['50K','100K'])
ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)

# ax[1][0].set_xticks([5, 25, 50, 100])
# ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[1][0].set(ylabel=None)
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
ax[1][0].set(xticklabels=[])  # remove the tick labels
ax[1][0].tick_params(bottom=False)
for bar in g3.patches:

    g3.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
dataselected= data[data["graphName"]=="DBpedia links"]
dataselected


ax[1][1].set_title('DBpedia links', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[1][1],hue="method", y="time",palette="colorblind")

g4.legend('',frameon=False)

# ax[0][2].set_xticks(['50K','100K'])
ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)

for bar in g4.patches:


    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')


ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][0].set(ylabel=None)
ax[2][0].set(xlabel=None)
# ax[0][2].set(xticklabels=[])  # remove the tick labels
ax[2][0].tick_params(bottom=False)


dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
dataselected


ax[2][0].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[2][0],hue="method", y="time",palette="colorblind")

g4.legend('',frameon=False)


# ax[2][0].set_xticks(['50K','100K'])
ax[2][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[2][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][0].set(ylabel=None)
ax[2][0].set(xlabel=None)

for bar in g4.patches:

    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')


ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][0].set(ylabel=None)
ax[2][0].set(xlabel=None)
# ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[2][0].tick_params(bottom=False)


dataselected= data[data["graphName"]=="Live Journal"]
dataselected


ax[2][1].set_title('Live Journal', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[2][1],hue="method", y="time",palette="colorblind")

g4.legend('',frameon=False)
#g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# ax[2][1].set_xticks(['50K','100K'])
ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[2][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][1].set(ylabel=None)
ax[2][1].set(xlabel=None)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')

#ax[2][1].loglog(basey=2,basex=2)
# ax[2][1].set_xticks([5, 25, 50, 100])
# ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[2][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][1].set(ylabel=None)
ax[2][1].set(xlabel=None)
# ax[1][0].set(xticklabels=[])  # remove the tick labels
ax[2][1].tick_params(bottom=False)


dataselected= data[data["graphName"]=="RMAT24-ER"]
dataselected


ax[3][0].set_title('RMAT24-ER', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[3][0],hue="method", y="time",palette="colorblind")

g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g4.legend('',frameon=False)

# ax[3][0].set_xticks(['50K','100K'])
ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][0].set(ylabel=None)
ax[3][0].set(xlabel=None)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
#ax[3][0].loglog(basey=2,basex=2)
# ax[3][0].set_xticks([5, 25, 50, 100])
# ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][0].set(ylabel=None)
ax[3][0].set(xlabel=None)
ax[3][0].set(xticklabels=[])  # remove the tick labels
ax[3][0].tick_params(bottom=False)



ax[3][1].set_title('RMAT24-G', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[3][1],hue="method", y="time",palette="colorblind")

g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# ax[3][1].set_xticks(['50K','100K'])
ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[3][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][1].set(ylabel=None)
ax[3][1].set(xlabel=None)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')

#ax[3][1].loglog(basey=2,basex=2)
# ax[3][1].set_xticks([5, 25, 50, 100])
# ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[3][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][1].set(ylabel=None)
ax[3][1].set(xlabel=None)
# ax[1][2].set(xticklabels=[])  # remove the tick labels
ax[3][1].tick_params(bottom=False)
g4.legend('',frameon=False)

dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected

ax[4][0].set_title('RMAT25-ER', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[4][0],hue="method", y="time",palette="colorblind")

g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# ax[4][0].set_xticks(['50K','100K'])
ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[4][0].set(ylabel=None)
ax[4][0].set(xlabel=None)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')

#ax[4][0].loglog(basey=2,basex=2)
# ax[4][0].set_xticks([5, 25, 50, 100])
# ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[4][0].set(ylabel=None)
ax[4][0].set(xlabel=None)
ax[4][0].set_xticklabels(('50K', '100K'))
g4.legend('',frameon=False)

dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected

ax[4][1].set_title('RMAT25-G', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[4][1],hue="method", y="time",palette="colorblind")

g4.legend('',frameon=False)

# ax[4][1].set_xticks(['50K','100K'])
ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[4][1].set(ylabel=None)
ax[4][1].set(xlabel=None)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')

#ax[4][1].loglog(basey=2,basex=2)
# ax[4][1].set_xticks([5, 25, 50, 100])
# ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][1].set(xlabel='Threads', ylabel='Execution Time ratio')
ax[4][1].set(ylabel=None)
ax[4][1].set(xlabel=None)
ax[4][1].set_xticklabels(('50K', '100K'))
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
# plt.xticks(fontsize=8, rotation=90)
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
plt.legend(bbox_to_anchor =(0.1,-0.87), loc='upper center', ncol=2, title='Method')
fig.text(0.04, 0.5, 'Time to update PR (msec)', va='center', rotation='vertical')
fig.text(0.5, 0.04, 'Change size', ha='center')
# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# plt.legend(['Dynamic Update','Dynamic Levelwise'], bbox_to_anchor=(1.05, 1),loc=2, borderaxespad=0.)
fig.savefig("comparisonwithGpuIPDPSworkshop.pdf",dpi=100,bbox_inches='tight')
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"
plt.yscale("log")
plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(2,5,figsize=[15,7])
fig.subplots_adjust(hspace=0.225, wspace=0.385)

sns.set_style('whitegrid')
# plt.yscale('log',base=2)
# fig, ax = plt.subplots(figsize=[9, 7])
# ax[0][0].set( yscale="log")
# ax[0][0].semilogy(basey=2)



data=pd.read_csv("scIA3.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]
# dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]


ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=8,fontweight="bold",pad=10)


g1=sns.lineplot(data=dataselected, ax=ax[0][0], x="threads", y="time",markers=True, hue="changes",  style="changes")

g1.legend('',frameon=False)

ax[0][0].set(xlabel=None)
# ax[0][0].yaxis.label.set_size(30)
ax[0][0].set(ylabel=None)

ax[0][0].set_xticks(range(len(dataselected)), labels=[1, 2, 4, 8,16,32,64])
ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
legend_prop = {'weight':'bold'}
# ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[0][0].tick_params(bottom=False)
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[0][0].yaxis.set_major_formatter(formatter)
# plt.xticks([0,2,4,8,16,32,64], ['1', '2', '4','8','16','32','64'])
# plt.legend(prop=legend_prop)
# # plt.savefig("Twitterwww.png",bbox_inches='tight')
# plt.show()

# ax[0][1].xaxis.set_minor_formatter(mticker.ScalarFormatter())
dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected
# dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]

ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g2=sns.lineplot(data=dataselected, ax=ax[0][1], x="threads", y="time",markers=True, hue="changes",  style="changes")
g2.legend('',frameon=False)

ax[0][1].set(xlabel=None)
ax[0][1].set(ylabel=None)



dataselected= data[data["graphName"]=="PubMed"]
dataselected
dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]
ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set( yscale="log")


ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][1].set_xticks([1, 2, 4, 8,16,32,64])
ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[0][1].set(xticklabels=[])  # remove the tick labels
ax[0][1].tick_params(bottom=False)
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[0][1].yaxis.set_major_formatter(formatter)

ax[0][2].yaxis.label.set_size(20)
ax[0][2].set_title('PubMed', fontname="Times New Roman", size=8,fontweight="bold",pad=10)
g3=sns.lineplot(data=dataselected, ax=ax[0][2], x="threads", y="time",markers=True, hue="changes",  style="changes")
g3.legend('',frameon=False)


ax[0][2].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][2].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][2].set_xticks([1,2,4,8,16,32,64])
ax[0][2].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[1][0].set(ylabel=None)
ax[0][2].set(ylabel=None)
ax[0][2].set(xlabel=None)
# ax[1][0].set(xticklabels=[])  # remove the tick labels
#ax[1][0].tick_params(bottom=False)
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[0][2].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="DBpedia links"]
dataselected
# dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]
ax[0][3].set_title('DBpedia links', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.lineplot(data=dataselected, ax=ax[0][3], x="threads", y="time",markers=True, hue="changes",  style="changes")
g4.legend('',frameon=False)


ax[0][3].set_xticks([1, 2, 4, 8,16,32,64])
ax[0][3].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][3].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][3].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][3].set(ylabel=None)
ax[0][3].set(xlabel=None)
# ax[0][2].set(xticklabels=[])  # remove the tick labels
# ax[0][2].tick_params(bottom=False)

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[0][3].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
dataselected
dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]
ax[0][4].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.lineplot(data=dataselected, ax=ax[0][4], x="threads", y="time",markers=True, hue="changes",  style="changes")
g4.legend('',frameon=False)




ax[0][4].set_xticks([1, 2, 4, 8,16,32,64])
ax[0][4].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][4].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][4].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][4].set(ylabel=None)
ax[0][4].set(xlabel=None)
# ax[0][4].set(xticklabels=[])  # remove the tick labels
# ax[0][4].tick_params(bottom=False)
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[0][4].yaxis.set_major_formatter(formatter)

dataselected= data[data["graphName"]=="Live Journal"]
dataselected
dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]
ax[1][0].set_title('Live Journal', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.lineplot(data=dataselected, ax=ax[1][0], x="threads", y="time",markers=True, hue="changes",  style="changes")
g4.legend('',frameon=False)


ax[1][0].set_xticks([1, 2, 4, 8,16,32,64])
ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
#ax[1][0].set(xticklabels=[])  # remove the tick labels
ax[1][0].tick_params(bottom=False)
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[1][0].yaxis.set_major_formatter(formatter)

dataselected= data[data["graphName"]=="RMAT24-ER"]
dataselected
dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]
ax[1][1].set_title('RMAT24-ER', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.lineplot(data=dataselected, ax=ax[1][1], x="threads", y="time",markers=True, hue="changes",  style="changes")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g4.legend('',frameon=False)




ax[1][1].set_xticks([1, 2, 4, 8,16,32,64])
ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)
# ax[1][2].set(xticklabels=[])  # remove the tick labels
ax[1][1].tick_params(bottom=False)
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[1][1].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="RMAT24-G"]
dataselected
dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]
ax[1][2].set_title('RMAT24-G', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.lineplot(data=dataselected, ax=ax[1][2], x="threads", y="time",markers=True, hue="changes",  style="changes")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)



ax[1][2].set_xticks([1, 2, 4, 8,16,32,64])
ax[1][2].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][2].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][2].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][2].set(ylabel=None)
ax[1][2].set(xlabel=None)
# ax[1][3].set(xticklabels=[])  # remove the tick labels
ax[1][2].tick_params(bottom=False)
g4.legend('',frameon=False)
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[1][2].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected
dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]
ax[1][3].set_title('RMAT25-ER', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.lineplot(data=dataselected, ax=ax[1][3], x="threads", y="time",markers=True, hue="changes",  style="changes")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


ax[1][3].set_xticks([1, 2, 4, 8,16,32,64])
ax[1][3].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][3].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][3].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][3].set(ylabel=None)
ax[1][3].set(xlabel=None)
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[1][3].yaxis.set_major_formatter(formatter)
g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected
dataselected=dataselected.loc[(dataselected['changes'] == '50M') | (dataselected['changes'] =='100M' )]
ax[1][4].set_title('RMAT25-G', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.lineplot(data=dataselected, ax=ax[1][4], x="threads", y="time",markers=True, hue="changes",  style="changes")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)



ax[1][4].set_xticks([1, 2, 4, 8,16,32,64])
ax[1][4].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][4].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][4].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][4].set(ylabel=None)
ax[1][4].set(xlabel=None)
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax[1][4].yaxis.set_major_formatter(formatter)

g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
#plt.xticks(fontsize=8, rotation=90)
plt.legend(bbox_to_anchor =(0.01,-0.12), loc='upper center', ncol=2, title='Changes')
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
fig.text(0.04, 0.5, 'Time to update PR (seconds)', va='center', rotation='vertical')
fig.text(0.5, 0.04, 'Threads', ha='center')
# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))


fig.savefig("sharedmemoryIPDPSworkshop.pdf",dpi=100,bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 42
#      39 # ax[0][0].yaxis.label.set_size(30)
#      40 ax[0][0].set(ylabel=None)
# ---> 42 ax[0][0].set_xticks(range(len(dataselected)), labels=[1, 2, 4, 8,16,32,64])
#      43 ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
#      44 legend_prop = {'weight':'bold'}
#
# File ~/PycharmProject/Icpp/venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:63, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      62 def wrapper(self, *args, **kwargs):
# ---> 63     return get_method(self)(*args, **kwargs)
#
# File ~/PycharmProject/Icpp/venv/lib/python3.10/site-packages/matplotlib/cbook/deprecation.py:451, in _make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     445 if len(args) > idx:
#     446     warn_deprecated(
# ...

# %%
import pandas as pd

df = pd.read_csv('merged_data.csv')


import seaborn as sns

df_select=df[:100]


sns.set(style='whitegrid')

sns.regplot(y="Pupil/Teacher Ratio [Public School] 2018-19",
                    x="pct_prof_math_hs",

                    data=df.head(300))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 13
#       8 df_select=df[:100]
#      11 sns.set(style='whitegrid')
# ---> 13 sns.regplot(y="Pupil/Teacher Ratio [Public School] 2018-19",
#      14                     x="pct_prof_math_hs",
#      15
#      16                     data=df.head(300))
#
# File ~/PycharmProject/Icpp/venv/lib/python3.10/site-packages/seaborn/regression.py:759, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     757 scatter_kws["marker"] = marker
#     758 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 759 plotter.plot(ax, scatter_kws, line_kws)
#     760 return ax
#
# ...

# %%
pip install sklearn

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"

plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(2,2,figsize=[10, 10])
fig.subplots_adjust(hspace=0.225, wspace=0.225)
sns.set_style('whitegrid')
# plt.yscale('log',base=2)
# fig, ax = plt.subplots(figsize=[9, 7])
# ax[0][0].set( yscale="log")
# ax[0][0].semilogy(basey=2)


color = ['purple','red']

data=pd.read_csv("scIA3accuracy.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]
dataselected
dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g1=sns.barplot(data=dataselected, x="percentage",ax=ax[0][0], y="score", hue="changes",palette="colorblind")
g1.legend('',frameon=False)
for bar in g1.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g1.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')



ax[0][0].set(xlabel=None)
# ax[0][0].yaxis.label.set_size(30)
ax[0][0].set(ylabel=None)
#ax[0][0].loglog(basey=2,basex=2)
# ax[0][0].set_xticks([10,15,20,25])
# # ax[0][0].set_xticks([5, 25, 50, 100])
# ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# legend_prop = {'weight':'bold'}
ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[0][0].tick_params(bottom=False)
# plt.xticks([0,2,4,8,16,32,64], ['1', '2', '4','8','16','32','64'])
# plt.legend(prop=legend_prop)
# # plt.savefig("Twitterwww.png",bbox_inches='tight')
# plt.show()


# ax[0][1].xaxis.set_minor_formatter(mticker.ScalarFormatter())
dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected
dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]

ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g2=sns.barplot(data=dataselected, ax=ax[0][1], x="percentage", y="score", hue="changes",palette="colorblind")
g2.legend('',frameon=False)
for bar in g2.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

ax[0][1].set(xlabel=None)
ax[0][1].set(ylabel=None)

# dataselected= data[data["graphName"]=="PubMed"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# # ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# # # ax[0][1].set( yscale="log")
# # ax[0][1].set_xticks([10,15, 20,25])
# # #ax[0][1].loglog(basey=2,basex=2)
# # ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# # ax[0][1].set_xticks([5, 25, 50, 100])
# # ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[0][1].set(xticklabels=[])  # remove the tick labels
# ax[0][1].tick_params(bottom=False)
# for bar in g2.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g2.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
# ax[1][0].yaxis.label.set_size(20)
# ax[1][0].set_title('PubMed', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
# g3=sns.barplot(data=dataselected, ax=ax[1][0], x="percentage", y="score", hue="changes", palette="colorblind")
# g3.legend('',frameon=False)
#
#
# #ax[1][0].loglog(basey=2,basex=2)
# ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
# # ax[1][0].set_xticks([10,15, 20,25])
# # ax[1][0].set_xticks([5, 25, 50, 100])
# # ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[1][0].set(ylabel=None)
# ax[1][0].set(ylabel=None)
# ax[1][0].set(xlabel=None)
#
# ax[1][0].set(xticklabels=[])  # remove the tick labels
# ax[1][0].tick_params(bottom=False)
# for bar in g3.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g3.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
# dataselected= data[data["graphName"]=="DBpedia links"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[1][1].set_title('DBpedia links', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[1][1], y="score",x="percentage", hue="changes", palette="colorblind")
# g4.legend('',frameon=False)
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
#
# #ax[1][1].loglog(basey=2,basex=2)
# # ax[0][1].set_xticks([10,15, 20,25])
# # ax[1][1].set_xticks([5, 25, 50, 100])
# # ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[1][1].set(ylabel=None)
# ax[1][1].set(xlabel=None)
# ax[1][1].set(xticklabels=[])  # remove the tick labels
# ax[1][1].tick_params(bottom=False)
#
#
# dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[2][0].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[2][0], x="percentage", y="score", hue="changes",palette="colorblind")
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# #ax[2][0].loglog(basey=2,basex=2)
# # ax[2][0].set_xticks([10,15, 20,25])
# # ax[2][0].set_xticks([5, 25, 50, 100])
# # ax[2][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[2][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[2][0].set(ylabel=None)
# ax[2][0].set(xlabel=None)
# ax[2][0].set(xticklabels=[])  # remove the tick labels
# ax[2][0].tick_params(bottom=False)
#
#
# dataselected= data[data["graphName"]=="Live Journal"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[2][1].set_title('Live Journal', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[2][1], x="percentage", y="score", hue="changes",palette="colorblind")
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# #ax[2][1].loglog(basey=2,basex=2)
# # ax[2][1].set_xticks([10,15, 20,25])
# # ax[2][1].set_xticks([5, 25, 50, 100])
# # ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[2][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[2][1].set(ylabel=None)
# ax[2][1].set(xlabel=None)
# ax[2][1].set(xticklabels=[])  # remove the tick labels
# ax[2][1].tick_params(bottom=False)
#
#
# dataselected= data[data["graphName"]=="RMAT24-ER"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[3][0].set_title('RMAT24-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[3][0], x="percentage", y="score", hue="changes", palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# g4.legend('',frameon=False)
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
# #ax[3][0].loglog(basey=2,basex=2)
# # ax[3][0].set_xticks([10,15, 20,25])
# # ax[3][0].set_xticks([5, 25, 50, 100])
# # ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[3][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[3][0].set(ylabel=None)
# ax[3][0].set(xlabel=None)
# ax[3][0].set(xticklabels=[])  # remove the tick labels
# ax[3][0].tick_params(bottom=False)
#
# dataselected= data[data["graphName"]=="RMAT24-G"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[3][1].set_title('RMAT24-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[3][1], x="percentage", y="score", hue="changes",palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# #ax[3][1].loglog(basey=2,basex=2)
# # ax[3][1].set_xticks([10,15,20,25])
# # ax[3][1].set_xticks([5, 25, 50, 100])
# # ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[3][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[3][1].set(ylabel=None)
# ax[3][1].set(xlabel=None)
# ax[3][1].set(xticklabels=[])  # remove the tick labels
# ax[3][1].tick_params(bottom=False)
# g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# dataselected=dataselected[dataselected["changes"]=="50M"]
ax[1][0].set_title('RMAT25-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][0], x="percentage", y="score", hue="changes",palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

#ax[4][0].loglog(basey=2,basex=2)
# ax[4][0].set_xticks([10,15, 20,25])
# ax[4][0].set_xticks([5, 25, 50, 100])
# ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[4][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected
# dataselected=dataselected[dataselected["changes"]=="50M"]

[dataselected["type"]=="kendall rank coefficient"]
ax[1][1].set_title('RMAT25-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][1], x="percentage", y="score", hue="changes",palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
g4.legend('',frameon=False)

#ax[4][1].loglog(basey=2,basex=2)
# ax[4][1].set_xticks([10,15, 20,25])
# ax[4][1].set_xticks([5, 25, 50, 100])
# ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[4][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)


# g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
#plt.xticks(fontsize=8, rotation=90)
#plt.suptitle('kendall Rank  Correlation coefficient',weight="bold")
plt.legend(bbox_to_anchor =(0.4,-0.17), loc='upper center', ncol=2, title='Changes')
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
fig.text(0.04, 0.5, 'kendall Rank  Correlation coefficient', va='center', rotation='vertical')
fig.text(0.5, 0.04, '% of nodes with high PR', ha='center')
# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

fig.savefig("AccuracyIPDPSkendallworkshop.pdf",dpi=100,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"

plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(5,2,figsize=[9, 7])
fig.subplots_adjust(hspace=0.225, wspace=0.225)
sns.set_style('whitegrid')
# plt.yscale('log',base=2)
# fig, ax = plt.subplots(figsize=[9, 7])
# ax[0][0].set( yscale="log")
# ax[0][0].semilogy(basey=2)

color=['red','blue','purple','black','Green','orange']

data=pd.read_csv("scIA3weakscaling.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]

color=['red','blue','purple','black','green','orange']

ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)


g1=sns.barplot(data=dataselected, ax=ax[0][0], x="changes", y="time", hue="threads",  palette="colorblind")

g1.legend('',frameon=False)


ax[0][0].set(xlabel=None)
# ax[0][0].yaxis.label.set_size(30)
ax[0][0].set(ylabel=None)

#ax[0][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
legend_prop = {'weight':'bold'}
ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[0][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[0][0].yaxis.set_major_formatter(formatter)
# plt.xticks([0,2,4,8,16,32,64], ['1', '2', '4','8','16','32','64'])
# plt.legend(prop=legend_prop)
# # plt.savefig("Twitterwww.png",bbox_inches='tight')
# plt.show()

for bar in g1.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g1.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[0][1].xaxis.set_minor_formatter(mticker.ScalarFormatter())
dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected


ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g2=sns.barplot(data=dataselected, ax=ax[0][1], x="changes", y="time", hue="threads",  palette="colorblind")
g2.legend('',frameon=False)

ax[0][1].set(xlabel=None)
ax[0][1].set(ylabel=None)
for bar in g2.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')


dataselected= data[data["graphName"]=="PubMed"]
dataselected

ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set( yscale="log")

# ax[0][1].loglog(basey=2,basex=2)
ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][1].set(xticklabels=[])  # remove the tick labels
ax[0][1].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[0][1].yaxis.set_major_formatter(formatter)

ax[1][0].yaxis.label.set_size(20)
ax[1][0].set_title('PubMed', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
g3=sns.barplot(data=dataselected, ax=ax[1][0], x="changes", y="time", hue="threads",  palette="colorblind")
g3.legend('',frameon=False)

for bar in g3.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g3.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
# ax[1][0].loglog(basey=2,basex=2)
ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[1][0].set_xticks([1,2,4,8,16,32,64])
# ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[1][0].set(ylabel=None)
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
ax[1][0].set(xticklabels=[])  # remove the tick labels
ax[1][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[1][0].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="DBpedia links"]
dataselected

ax[1][1].set_title('DBpedia links', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][1], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend('',frameon=False)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
#ax[1][1].loglog(basey=2,basex=2)
#ax[1][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)
ax[1][1].set(xticklabels=[])  # remove the tick labels
ax[1][1].tick_params(bottom=False)

# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[1][1].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
dataselected

ax[2][0].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[2][0], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend('',frameon=False)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[2][0].loglog(basey=2,basex=2)
# ax[2][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[2][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[2][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][0].set(ylabel=None)
ax[2][0].set(xlabel=None)
ax[2][0].set(xticklabels=[])  # remove the tick labels
ax[2][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[2][0].yaxis.set_major_formatter(formatter)

dataselected= data[data["graphName"]=="Live Journal"]
dataselected

ax[2][1].set_title('Live Journal', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[2][1], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend('',frameon=False)
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Threads', borderaxespad=0.)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
# ax[2][1].loglog(basey=2,basex=2)
# ax[2][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[2][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][1].set(ylabel=None)
ax[2][1].set(xlabel=None)
ax[2][1].set(xticklabels=[])  # remove the tick labels
ax[2][1].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[2][1].yaxis.set_major_formatter(formatter)

dataselected= data[data["graphName"]=="RMAT24-ER"]
dataselected

ax[3][0].set_title('RMAT24-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[3][0], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g4.legend('',frameon=False)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

#ax[3][0].loglog(basey=2,basex=2)
# ax[3][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][0].set(ylabel=None)
ax[3][0].set(xlabel=None)
ax[3][0].set(xticklabels=[])  # remove the tick labels
ax[3][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[3][0].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="RMAT24-G"]
dataselected

ax[3][1].set_title('RMAT24-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[3][1], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[3][1].loglog(basey=2,basex=2)
# ax[3][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][1].set(ylabel=None)
ax[3][1].set(xlabel=None)
ax[3][1].set(xticklabels=[])  # remove the tick labels
ax[3][1].tick_params(bottom=False)
g4.legend('',frameon=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[3][1].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected

ax[4][0].set_title('RMAT25-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[4][0], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
#ax[4][0].loglog(basey=2,basex=2)
#ax[4][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[4][0].set(ylabel=None)
ax[4][0].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[4][0].yaxis.set_major_formatter(formatter)
g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected

ax[4][1].set_title('RMAT25-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[4][1], x="changes", y="time", hue="threads",  palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Threads', borderaxespad=0.)
g4.legend('',frameon=False)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

#ax[4][1].loglog(basey=2,basex=2)
#ax[4][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[4][1].set(ylabel=None)
ax[4][1].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[4][1].yaxis.set_major_formatter(formatter)

# g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
#plt.xticks(fontsize=8, rotation=90)
plt.legend(bbox_to_anchor =(0.5,-0.87), loc='upper center', ncol=6, title='Threads')
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
fig.text(0.04, 0.5, 'Time to update PR (seconds)', va='center', rotation='vertical')
fig.text(0.5, 0.04, 'Change Size', ha='center')
# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))


fig.savefig("sharedmemoryweakscalingIPDPSworkshop.pdf",dpi=100,bbox_inches='tight')
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"

plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(2,2,figsize=[10, 10])
fig.subplots_adjust(hspace=0.225, wspace=0.225)
sns.set_style('whitegrid')
# plt.yscale('log',base=2)
# fig, ax = plt.subplots(figsize=[9, 7])
# ax[0][0].set( yscale="log")
# ax[0][0].semilogy(basey=2)


data=pd.read_csv("scIA3etc.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]
color=['purple','green']


ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=10,fontweight="bold",pad=12)


g1=sns.barplot(data=dataselected, ax=ax[0][0], x="etc", y="F1", hue="changes",  palette="colorblind")

g1.legend('',frameon=False)


ax[0][0].set(xlabel=None)
# ax[0][0].yaxis.label.set_size(30)
ax[0][0].set(ylabel=None)

#ax[0][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
legend_prop = {'weight':'bold'}
ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[0][0].tick_params(bottom=False) 
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[0][0].yaxis.set_major_formatter(formatter) 
# plt.xticks([0,2,4,8,16,32,64], ['1', '2', '4','8','16','32','64'])
# plt.legend(prop=legend_prop)
# # plt.savefig("Twitterwww.png",bbox_inches='tight')
# plt.show()

for bar in g1.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g1.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[0][1].xaxis.set_minor_formatter(mticker.ScalarFormatter())
dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected


ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=10,fontweight="bold",pad=12)

g2=sns.barplot(data=dataselected, ax=ax[0][1], x="etc", y="F1", hue="changes",  palette="colorblind")
g2.legend('',frameon=False)

ax[0][1].set(xlabel=None)
ax[0][1].set(ylabel=None)
for bar in g2.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')


dataselected= data[data["graphName"]=="PubMed"]
dataselected

ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set( yscale="log")

# ax[0][1].loglog(basey=2,basex=2)
ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][1].set(xticklabels=[])  # remove the tick labels
ax[0][1].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[0][1].yaxis.set_major_formatter(formatter) 
#
# ax[1][0].yaxis.label.set_size(20)
# ax[1][0].set_title('PubMed', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
# g3=sns.barplot(data=dataselected, ax=ax[1][0], x="etc", y="F1", hue="changes",  palette="colorblind")
# g3.legend('',frameon=False)
#
# for bar in g3.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g3.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
# # ax[1][0].loglog(basey=2,basex=2)
# ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
# # ax[1][0].set_xticks([1,2,4,8,16,32,64])
# # ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[1][0].set(ylabel=None)
# ax[1][0].set(ylabel=None)
# ax[1][0].set(xlabel=None)
# ax[1][0].set(xticklabels=[])  # remove the tick labels
# ax[1][0].tick_params(bottom=False)
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[1][0].yaxis.set_major_formatter(formatter)
# dataselected= data[data["graphName"]=="DBpedia links"]
# dataselected
#
# ax[1][1].set_title('DBpedia links', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[1][1], x="etc", y="F1", hue="changes",  palette="colorblind")
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
# #ax[1][1].loglog(basey=2,basex=2)
# #ax[1][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[1][1].set(ylabel=None)
# ax[1][1].set(xlabel=None)
# ax[1][1].set(xticklabels=[])  # remove the tick labels
# ax[1][1].tick_params(bottom=False)
#
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[1][1].yaxis.set_major_formatter(formatter)
# dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
# dataselected
#
# ax[2][0].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[2][0], x="etc", y="F1", hue="changes",  palette="colorblind")
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# # ax[2][0].loglog(basey=2,basex=2)
# # ax[2][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[2][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[2][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[2][0].set(ylabel=None)
# ax[2][0].set(xlabel=None)
# ax[2][0].set(xticklabels=[])  # remove the tick labels
# ax[2][0].tick_params(bottom=False)
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[2][0].yaxis.set_major_formatter(formatter)
#
# dataselected= data[data["graphName"]=="Live Journal"]
# dataselected
#
# ax[2][1].set_title('Live Journal', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[2][1], x="etc", y="F1", hue="changes",  palette="colorblind")
# g4.legend('',frameon=False)
# #g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Changes', borderaxespad=0.)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
# # ax[2][1].loglog(basey=2,basex=2)
# # ax[2][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[2][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[2][1].set(ylabel=None)
# ax[2][1].set(xlabel=None)
# ax[2][1].set(xticklabels=[])  # remove the tick labels
# ax[2][1].tick_params(bottom=False)
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[2][1].yaxis.set_major_formatter(formatter)
#
# dataselected= data[data["graphName"]=="RMAT24-ER"]
# dataselected
#
# ax[3][0].set_title('RMAT24-ER', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[3][0], x="etc", y="F1", hue="changes",  palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# #ax[3][0].loglog(basey=2,basex=2)
# # ax[3][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[3][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[3][0].set(ylabel=None)
# ax[3][0].set(xlabel=None)
# ax[3][0].set(xticklabels=[])  # remove the tick labels
# ax[3][0].tick_params(bottom=False)
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[3][0].yaxis.set_major_formatter(formatter)
# dataselected= data[data["graphName"]=="RMAT24-G"]
# dataselected
#
# ax[3][1].set_title('RMAT24-G', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[3][1], x="etc", y="F1", hue="changes",  palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# # ax[3][1].loglog(basey=2,basex=2)
# # ax[3][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[3][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[3][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[3][1].set(ylabel=None)
# ax[3][1].set(xlabel=None)
# ax[3][1].set(xticklabels=[])  # remove the tick labels
# ax[3][1].tick_params(bottom=False)
# g4.legend('',frameon=False)
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[3][1].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected

ax[1][0].set_title('RMAT25-ER', fontname="Times New Roman", size=10,fontweight="bold",pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][0], x="etc", y="F1", hue="changes",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
#ax[4][0].loglog(basey=2,basex=2)
#ax[4][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[4][0].yaxis.set_major_formatter(formatter) 
g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected

ax[1][1].set_title('RMAT25-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][1], x="etc", y="F1", hue="changes",  palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Threads', borderaxespad=0.)
g4.legend('',frameon=False)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 10),
                   textcoords='offset points')

#ax[4][1].loglog(basey=2,basex=2)
#ax[4][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[4][1].yaxis.set_major_formatter(formatter) 

# g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
# plt.xticks(fontsize=8, rotation=90)
plt.legend(bbox_to_anchor =(0.45,-0.17), loc='upper center', ncol=2, title='Changes')
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
fig.text(0.04, 0.5, 'F1-Score', va='center', rotation='vertical')
fig.text(0.5, 0.04, 'Early Termination Condition', ha='center')
# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))


fig.savefig("sharedmemoryetcIPDPSworkshop.pdf",dpi=100,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"

plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(2,2,figsize=[10, 10])
sns.set_style('whitegrid')
fig.subplots_adjust(hspace=0.225, wspace=0.225)
sns.set_style('whitegrid')
# plt.yscale('log',base=2)
# fig, ax = plt.subplots(figsize=[9, 7])
# ax[0][0].set( yscale="log")
# ax[0][0].semilogy(basey=2)


color = ['blue','red']

data=pd.read_csv("scIA3accuracy.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]
dataselected
dataselected=dataselected[dataselected["type"]=="F1-score"]
ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g1=sns.barplot(data=dataselected, x="percentage",ax=ax[0][0], y="score", hue="changes",palette="colorblind")
g1.legend('',frameon=False)
for bar in g1.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g1.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=10, xytext=(0, 8),
                   textcoords='offset points')



ax[0][0].set(xlabel=None)
# ax[0][0].yaxis.label.set_size(30)
ax[0][0].set(ylabel=None)
#ax[0][0].loglog(basey=2,basex=2)
# ax[0][0].set_xticks([10,15,20,25])
# # ax[0][0].set_xticks([5, 25, 50, 100])
# ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# legend_prop = {'weight':'bold'}
ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[0][0].tick_params(bottom=False) 
# plt.xticks([0,2,4,8,16,32,64], ['1', '2', '4','8','16','32','64'])
# plt.legend(prop=legend_prop)
# # plt.savefig("Twitterwww.png",bbox_inches='tight')
# plt.show()


# ax[0][1].xaxis.set_minor_formatter(mticker.ScalarFormatter())
dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected
dataselected=dataselected[dataselected["type"]=="F1-score"]

ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g2=sns.barplot(data=dataselected, ax=ax[0][1], x="percentage", y="score", hue="changes",palette="colorblind")
g2.legend('',frameon=False)
for bar in g2.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=10, xytext=(0, 8),
                   textcoords='offset points')

ax[0][1].set(xlabel=None)
ax[0][1].set(ylabel=None)

dataselected= data[data["graphName"]=="PubMed"]
dataselected
# dataselected=dataselected[dataselected["changes"]=="50M"]
dataselected=dataselected[dataselected["type"]=="F1-score"]
# ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# # ax[0][1].set( yscale="log")
# ax[0][1].set_xticks([10,15, 20,25])
# #ax[0][1].loglog(basey=2,basex=2)
# ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set_xticks([5, 25, 50, 100])
# ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][1].set(xticklabels=[])  # remove the tick labels
ax[0][1].tick_params(bottom=False)
for bar in g2.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=10, xytext=(0, 8),
                   textcoords='offset points')
# ax[1][0].yaxis.label.set_size(20)
# ax[1][0].set_title('PubMed', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
# g3=sns.barplot(data=dataselected, ax=ax[1][0], x="percentage", y="score", hue="changes", palette="colorblind")
# g3.legend('',frameon=False)
#
#
# #ax[1][0].loglog(basey=2,basex=2)
# ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
# # ax[1][0].set_xticks([10,15, 20,25])
# # ax[1][0].set_xticks([5, 25, 50, 100])
# # ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[1][0].set(ylabel=None)
# ax[1][0].set(ylabel=None)
# ax[1][0].set(xlabel=None)
#
# ax[1][0].set(xticklabels=[])  # remove the tick labels
# ax[1][0].tick_params(bottom=False)
# for bar in g3.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g3.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                   size=10, xytext=(0, 8),
#                    textcoords='offset points')
# dataselected= data[data["graphName"]=="DBpedia links"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="F1-score"]
# ax[1][1].set_title('DBpedia links', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[1][1], y="score",x="percentage", hue="changes", palette="colorblind")
# g4.legend('',frameon=False)
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                   size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
#
# #ax[1][1].loglog(basey=2,basex=2)
# # ax[0][1].set_xticks([10,15, 20,25])
# # ax[1][1].set_xticks([5, 25, 50, 100])
# # ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[1][1].set(ylabel=None)
# ax[1][1].set(xlabel=None)
# ax[1][1].set(xticklabels=[])  # remove the tick labels
# ax[1][1].tick_params(bottom=False)
#
#
# dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="F1-score"]
# ax[2][0].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[2][0], x="percentage", y="score", hue="changes",palette="colorblind")
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                   size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# #ax[2][0].loglog(basey=2,basex=2)
# # ax[2][0].set_xticks([10,15, 20,25])
# # ax[2][0].set_xticks([5, 25, 50, 100])
# # ax[2][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[2][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[2][0].set(ylabel=None)
# ax[2][0].set(xlabel=None)
# ax[2][0].set(xticklabels=[])  # remove the tick labels
# ax[2][0].tick_params(bottom=False)
#
#
# dataselected= data[data["graphName"]=="Live Journal"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="F1-score"]
# ax[2][1].set_title('Live Journal', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[2][1], x="percentage", y="score", hue="changes",palette="colorblind")
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                   size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# #ax[2][1].loglog(basey=2,basex=2)
# # ax[2][1].set_xticks([10,15, 20,25])
# # ax[2][1].set_xticks([5, 25, 50, 100])
# # ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[2][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[2][1].set(ylabel=None)
# ax[2][1].set(xlabel=None)
# ax[2][1].set(xticklabels=[])  # remove the tick labels
# ax[2][1].tick_params(bottom=False)
#
#
# dataselected= data[data["graphName"]=="RMAT24-ER"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="F1-score"]
# ax[3][0].set_title('RMAT24-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[3][0], x="percentage", y="score", hue="changes", palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# g4.legend('',frameon=False)
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                   size=10, xytext=(0, 8),
#                    textcoords='offset points')
# #ax[3][0].loglog(basey=2,basex=2)
# # ax[3][0].set_xticks([10,15, 20,25])
# # ax[3][0].set_xticks([5, 25, 50, 100])
# # ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[3][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[3][0].set(ylabel=None)
# ax[3][0].set(xlabel=None)
# ax[3][0].set(xticklabels=[])  # remove the tick labels
# ax[3][0].tick_params(bottom=False)
#
# dataselected= data[data["graphName"]=="RMAT24-G"]
# dataselected
# # dataselected=dataselected[dataselected["changes"]=="50M"]
# dataselected=dataselected[dataselected["type"]=="F1-score"]
# ax[3][1].set_title('RMAT24-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[3][1], x="percentage", y="score", hue="changes",palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                   size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# #ax[3][1].loglog(basey=2,basex=2)
# # ax[3][1].set_xticks([10,15,20,25])
# # ax[3][1].set_xticks([5, 25, 50, 100])
# # ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[3][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[3][1].set(ylabel=None)
# ax[3][1].set(xlabel=None)
# ax[3][1].set(xticklabels=[])  # remove the tick labels
# ax[3][1].tick_params(bottom=False)
# g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected=dataselected[dataselected["type"]=="F1-score"]
# dataselected=dataselected[dataselected["changes"]=="50M"]
ax[1][0].set_title('RMAT25-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][0], x="percentage", y="score", hue="changes",palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=10, xytext=(0, 8),
                   textcoords='offset points')

#ax[4][0].loglog(basey=2,basex=2)
# ax[4][0].set_xticks([10,15, 20,25])
# ax[4][0].set_xticks([5, 25, 50, 100])
# ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[4][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected
# dataselected=dataselected[dataselected["changes"]=="50M"]

[dataselected["type"]=="F1-score"]
ax[1][1].set_title('RMAT25-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][1], x="percentage", y="score", hue="changes",palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=10, xytext=(0, 8),
                   textcoords='offset points')


#ax[4][1].loglog(basey=2,basex=2)
# ax[4][1].set_xticks([10,15, 20,25])
# ax[4][1].set_xticks([5, 25, 50, 100])
# ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[4][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)


g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
# plt.xticks(fontsize=8, rotation=90)
# plt.suptitle('F-1 Score',weight="bold")
plt.legend(bbox_to_anchor =(0.2,-0.27), loc='upper center', ncol=6, title='Threads')
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
fig.text(0.04, 0.5, 'F1- Score', va='center', rotation='vertical', fontsize=12)
fig.text(0.5, 0.04, 'Percentage of vertices with high PR', ha='center',fontsize=12)
# # Put a legend to tPercentage right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

fig.savefig("AccuracyIPDPSworkshop.pdf",dpi=100,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"

plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(5,2,figsize=[10, 10])
fig.subplots_adjust(hspace=0.725, wspace=0.225)
sns.set_style('whitegrid')
# plt.yscale('log',base=2)
# fig, ax = plt.subplots(figsize=[9, 7])
# ax[0][0].set( yscale="log")
# ax[0][0].semilogy(basey=2)

color=['red','blue','purple','black','Green','orange']

data=pd.read_csv("scIA3weakscaling.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]

color=['red','blue','purple','black','green','orange']

ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)


g1=sns.barplot(data=dataselected, ax=ax[0][0], x="changes", y="time", hue="threads",  palette="colorblind")

g1.legend('',frameon=False)


ax[0][0].set(xlabel=None)
# ax[0][0].yaxis.label.set_size(30)
ax[0][0].set(ylabel=None)

#ax[0][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
legend_prop = {'weight':'bold'}
ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[0][0].tick_params(bottom=False) 
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[0][0].yaxis.set_major_formatter(formatter) 
# plt.xticks([0,2,4,8,16,32,64], ['1', '2', '4','8','16','32','64'])
# plt.legend(prop=legend_prop)
# # plt.savefig("Twitterwww.png",bbox_inches='tight')
# plt.show()

for bar in g1.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g1.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[0][1].xaxis.set_minor_formatter(mticker.ScalarFormatter())
dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected


ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g2=sns.barplot(data=dataselected, ax=ax[0][1], x="changes", y="time", hue="threads",  palette="colorblind")
g2.legend('',frameon=False)

ax[0][1].set(xlabel=None)
ax[0][1].set(ylabel=None)
for bar in g2.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')


dataselected= data[data["graphName"]=="PubMed"]
dataselected

ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set( yscale="log")

# ax[0][1].loglog(basey=2,basex=2)
ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][1].set(xticklabels=[])  # remove the tick labels
ax[0][1].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[0][1].yaxis.set_major_formatter(formatter) 

ax[1][0].yaxis.label.set_size(20)
ax[1][0].set_title('PubMed', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
g3=sns.barplot(data=dataselected, ax=ax[1][0], x="changes", y="time", hue="threads",  palette="colorblind")
g3.legend('',frameon=False)

for bar in g3.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g3.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
# ax[1][0].loglog(basey=2,basex=2)
ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[1][0].set_xticks([1,2,4,8,16,32,64])
# ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[1][0].set(ylabel=None)
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
ax[1][0].set(xticklabels=[])  # remove the tick labels
ax[1][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[1][0].yaxis.set_major_formatter(formatter) 
dataselected= data[data["graphName"]=="DBpedia links"]
dataselected

ax[1][1].set_title('DBpedia links', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][1], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend('',frameon=False)

for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
#ax[1][1].loglog(basey=2,basex=2)
#ax[1][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)
ax[1][1].set(xticklabels=[])  # remove the tick labels
ax[1][1].tick_params(bottom=False)

# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[1][1].yaxis.set_major_formatter(formatter) 
dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
dataselected

ax[2][0].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[2][0], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend('',frameon=False)

for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[2][0].loglog(basey=2,basex=2)
# ax[2][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[2][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[2][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][0].set(ylabel=None)
ax[2][0].set(xlabel=None)
ax[2][0].set(xticklabels=[])  # remove the tick labels
ax[2][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[2][0].yaxis.set_major_formatter(formatter) 

dataselected= data[data["graphName"]=="Live Journal"]
dataselected

ax[2][1].set_title('Live Journal', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[2][1], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend('',frameon=False)
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Threads', borderaxespad=0.)

for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
# ax[2][1].loglog(basey=2,basex=2)
# ax[2][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[2][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][1].set(ylabel=None)
ax[2][1].set(xlabel=None)
ax[2][1].set(xticklabels=[])  # remove the tick labels
ax[2][1].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[2][1].yaxis.set_major_formatter(formatter) 

dataselected= data[data["graphName"]=="RMAT24-ER"]
dataselected

ax[3][0].set_title('RMAT24-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[3][0], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g4.legend('',frameon=False)

for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

#ax[3][0].loglog(basey=2,basex=2)
# ax[3][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][0].set(ylabel=None)
ax[3][0].set(xlabel=None)
ax[3][0].set(xticklabels=[])  # remove the tick labels
ax[3][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[3][0].yaxis.set_major_formatter(formatter) 
dataselected= data[data["graphName"]=="RMAT24-G"]
dataselected

ax[3][1].set_title('RMAT24-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[3][1], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[3][1].loglog(basey=2,basex=2)
# ax[3][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][1].set(ylabel=None)
ax[3][1].set(xlabel=None)
ax[3][1].set(xticklabels=[])  # remove the tick labels
ax[3][1].tick_params(bottom=False)
g4.legend('',frameon=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[3][1].yaxis.set_major_formatter(formatter) 
dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected

ax[4][0].set_title('RMAT25-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[4][0], x="changes", y="time", hue="threads",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
#ax[4][0].loglog(basey=2,basex=2)
#ax[4][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[4][0].set(ylabel=None)
ax[4][0].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[4][0].yaxis.set_major_formatter(formatter) 
g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected

ax[4][1].set_title('RMAT25-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[4][1], x="changes", y="time", hue="threads",  palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Threads', borderaxespad=0.)
g4.legend('',frameon=False)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

#ax[4][1].loglog(basey=2,basex=2)
#ax[4][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[4][1].set(ylabel=None)
ax[4][1].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[4][1].yaxis.set_major_formatter(formatter) 

# g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
#plt.xticks(fontsize=8, rotation=90)
plt.legend(bbox_to_anchor =(0.5,-0.87), loc='upper center', ncol=6, title='Threads')
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
fig.text(0.04, 0.5, 'Time to update PR (seconds)', va='center', rotation='vertical')
fig.text(0.5, 0.04, 'Change Size', ha='center')
# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))


fig.savefig("sharedmemoryweakscalingIPDPSworkshop.pdf",dpi=100,bbox_inches='tight')
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"

plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(5,2,figsize=[10, 10])
fig.subplots_adjust(hspace=0.725, wspace=0.225)
sns.set_style('whitegrid')
# plt.yscale('log',base=2)
# fig, ax = plt.subplots(figsize=[9, 7])
# ax[0][0].set( yscale="log")
# ax[0][0].semilogy(basey=2)

color=['red','blue','purple','black','Green','orange']

data=pd.read_csv("scIA3weakscalingdeletion.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]

color=['red','blue','purple','black','green','orange']

ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)


g1=sns.barplot(data=dataselected, ax=ax[0][0], x="%", y="time", hue="threads",  palette="colorblind")

g1.legend('',frameon=False)


ax[0][0].set(xlabel=None)
# ax[0][0].yaxis.label.set_size(30)
ax[0][0].set(ylabel=None)

#ax[0][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
legend_prop = {'weight':'bold'}
ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[0][0].tick_params(bottom=False) 
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[0][0].yaxis.set_major_formatter(formatter) 
# plt.xticks([0,2,4,8,16,32,64], ['1', '2', '4','8','16','32','64'])
# plt.legend(prop=legend_prop)
# # plt.savefig("Twitterwww.png",bbox_inches='tight')
# plt.show()

for bar in g1.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g1.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[0][1].xaxis.set_minor_formatter(mticker.ScalarFormatter())
dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected


ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g2=sns.barplot(data=dataselected, ax=ax[0][1], x="%", y="time", hue="threads",  palette="colorblind")
g2.legend('',frameon=False)

ax[0][1].set(xlabel=None)
ax[0][1].set(ylabel=None)
for bar in g2.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')


dataselected= data[data["graphName"]=="PubMed"]
dataselected

ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set( yscale="log")

# ax[0][1].loglog(basey=2,basex=2)
ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][1].set(xticklabels=[])  # remove the tick labels
ax[0][1].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[0][1].yaxis.set_major_formatter(formatter) 

ax[1][0].yaxis.label.set_size(20)
ax[1][0].set_title('PubMed', fontname="Times New Roman", size=10,fontweight="bold", pad=12)
g3=sns.barplot(data=dataselected, ax=ax[1][0], x="%", y="time", hue="threads",  palette="colorblind")
g3.legend('',frameon=False)

for bar in g3.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g3.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
# ax[1][0].loglog(basey=2,basex=2)
ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[1][0].set_xticks([1,2,4,8,16,32,64])
# ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[1][0].set(ylabel=None)
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
ax[1][0].set(xticklabels=[])  # remove the tick labels
ax[1][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[1][0].yaxis.set_major_formatter(formatter) 
dataselected= data[data["graphName"]=="DBpedia links"]
dataselected

ax[1][1].set_title('DBpedia links', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][1], x="%", y="time", hue="threads",  palette="colorblind")
g4.legend('',frameon=False)

for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
#ax[1][1].loglog(basey=2,basex=2)
#ax[1][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)
ax[1][1].set(xticklabels=[])  # remove the tick labels
ax[1][1].tick_params(bottom=False)

# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[1][1].yaxis.set_major_formatter(formatter) 
dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
dataselected

ax[2][0].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[2][0], x="%", y="time", hue="threads",  palette="colorblind")
g4.legend('',frameon=False)

for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[2][0].loglog(basey=2,basex=2)
# ax[2][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[2][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[2][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][0].set(ylabel=None)
ax[2][0].set(xlabel=None)
ax[2][0].set(xticklabels=[])  # remove the tick labels
ax[2][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[2][0].yaxis.set_major_formatter(formatter) 

dataselected= data[data["graphName"]=="Live Journal"]
dataselected

ax[2][1].set_title('Live Journal', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[2][1], x="%", y="time", hue="threads",  palette="colorblind")
g4.legend('',frameon=False)
#g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Threads', borderaxespad=0.)

for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
# ax[2][1].loglog(basey=2,basex=2)
# ax[2][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[2][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[2][1].set(ylabel=None)
ax[2][1].set(xlabel=None)
ax[2][1].set(xticklabels=[])  # remove the tick labels
ax[2][1].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[2][1].yaxis.set_major_formatter(formatter) 

dataselected= data[data["graphName"]=="RMAT24-ER"]
dataselected

ax[3][0].set_title('RMAT24-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[3][0], x="%", y="time", hue="threads",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g4.legend('',frameon=False)

for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

#ax[3][0].loglog(basey=2,basex=2)
# ax[3][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][0].set(ylabel=None)
ax[3][0].set(xlabel=None)
ax[3][0].set(xticklabels=[])  # remove the tick labels
ax[3][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[3][0].yaxis.set_major_formatter(formatter) 
dataselected= data[data["graphName"]=="RMAT24-G"]
dataselected

ax[3][1].set_title('RMAT24-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[3][1], x="%", y="time", hue="threads",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[3][1].loglog(basey=2,basex=2)
# ax[3][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[3][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[3][1].set(ylabel=None)
ax[3][1].set(xlabel=None)
ax[3][1].set(xticklabels=[])  # remove the tick labels
ax[3][1].tick_params(bottom=False)
g4.legend('',frameon=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[3][1].yaxis.set_major_formatter(formatter) 
dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected

ax[4][0].set_title('RMAT25-ER', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[4][0], x="%", y="time", hue="threads",  palette="colorblind")
#g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
#ax[4][0].loglog(basey=2,basex=2)
#ax[4][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[4][0].set(ylabel=None)
ax[4][0].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[4][0].yaxis.set_major_formatter(formatter) 
g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected

ax[4][1].set_title('RMAT25-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[4][1], x="%", y="time", hue="threads",  palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Threads', borderaxespad=0.)
g4.legend('',frameon=False)
for bar in g4.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

#ax[4][1].loglog(basey=2,basex=2)
#ax[4][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[4][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[4][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[4][1].set(ylabel=None)
ax[4][1].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True) 
# formatter.set_powerlimits((-1,1)) 
# ax[4][1].yaxis.set_major_formatter(formatter) 

# g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
# plt.xticks(fontsize=8, rotation=90)
plt.legend(bbox_to_anchor =(0.1,-0.89), loc='upper center', ncol=6, title='Threads')
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
fig.text(0.04, 0.5, 'Time to update PR (seconds)', va='center', rotation='vertical')
fig.text(0.5, 0.04, 'Insertion %', ha='center')
# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))


fig.savefig("sharedmemoryweakscalingdeletionIPDPSworkshop.pdf",dpi=100,bbox_inches='tight')
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"

plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(2,2,figsize=[10, 10])
fig.subplots_adjust(hspace=0.725, wspace=0.485)
sns.set_style('whitegrid')


data=pd.read_csv("scIA3gpucomparison.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]
dataselected

ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g1=sns.barplot(data=dataselected, x="changes",ax=ax[0][0],hue="method", y="time",palette="colorblind")

g1.legend('',frameon=False)
for bar in g1.patches:


    g1.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
# ax[0][0].set_xticks(['50K','100K'])
ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set(ylabel=None)
ax[0][0].set(xlabel=None)
ax[0][0].set(xticklabels=[])


dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected



g2=sns.barplot(data=dataselected, x="changes",ax=ax[0][1],hue="method", y="time",palette="colorblind")

g2.legend('',frameon=False)


ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

# ax[0][1].set_xticks(['50K','100K'])

for bar in g2.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set(ylabel=None)
ax[0][1].set(xlabel=None)



dataselected= data[data["graphName"]=="PubMed"]
dataselected

# ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# # ax[0][1].set( yscale="log")

# #ax[0][1].loglog(basey=2,basex=2)
# ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[0][1].set_xticks([5, 25, 50, 100])
# ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][1].set(xticklabels=[])  # remove the tick labels
ax[0][1].tick_params(bottom=False)
for bar in g2.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
ax[0][2].yaxis.label.set_size(20)
ax[0][2].set_title('PubMed', fontname="Times New Roman", size=8,fontweight="bold",pad=10)
g3=sns.barplot(data=dataselected, x="changes",ax=ax[0][2],hue="method", y="time",palette="colorblind")

g3.legend('',frameon=False)


# ax[1][0].set_xticks(['50K','100K'])
ax[0][2].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][2].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][2].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][2].set(ylabel=None)
ax[0][2].set(xlabel=None)

#ax[1][0].loglog(basey=2,basex=2)
ax[0][2].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][2].set(xlabel='Threads', ylabel='Time to update PR')
# ax[1][0].set_xticks([5, 25, 50, 100])
# ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[1][0].set(ylabel=None)
ax[0][2].set(ylabel=None)
ax[0][2].set(xlabel=None)
ax[0][2].set(xticklabels=[])  # remove the tick labels
ax[0][2].tick_params(bottom=False)
for bar in g3.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g3.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
dataselected= data[data["graphName"]=="DBpedia links"]
dataselected


ax[0][3].set_title('DBpedia links', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[0][3],hue="method", y="time",palette="colorblind")

g4.legend('',frameon=False)

# ax[0][2].set_xticks(['50K','100K'])
ax[0][3].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][3].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][3].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][3].set(ylabel=None)
ax[0][3].set(xlabel=None)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')


#ax[0][2].loglog(basey=2,basex=2)
# ax[0][2].set_xticks([5, 25, 50, 100])
# ax[0][2].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[0][2].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][3].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][3].set(ylabel=None)
ax[0][3].set(xlabel=None)
# ax[0][2].set(xticklabels=[])  # remove the tick labels
ax[0][3].tick_params(bottom=False)


dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
dataselected


ax[0][4].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[0][4],hue="method", y="time",palette="colorblind")

g4.legend('',frameon=False)


# ax[2][0].set_xticks(['50K','100K'])
ax[0][4].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[0][4].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][4].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][4].set(ylabel=None)
ax[0][4].set(xlabel=None)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')

#ax[2][0].loglog(basey=2,basex=2)
# ax[2][0].set_xticks([5, 25, 50, 100])
# ax[2][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[2][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[0][4].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][4].set(ylabel=None)
ax[0][4].set(xlabel=None)
# ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[0][4].tick_params(bottom=False)


dataselected= data[data["graphName"]=="Live Journal"]
dataselected


ax[1][0].set_title('Live Journal', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[1][0],hue="method", y="time",palette="colorblind")

g4.legend('',frameon=False)
#g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# ax[2][1].set_xticks(['50K','100K'])
ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')

#ax[2][1].loglog(basey=2,basex=2)
# ax[2][1].set_xticks([5, 25, 50, 100])
# ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
# ax[1][0].set(xticklabels=[])  # remove the tick labels
ax[1][0].tick_params(bottom=False)


dataselected= data[data["graphName"]=="RMAT24-ER"]
dataselected


ax[1][1].set_title('RMAT24-ER', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[1][1],hue="method", y="time",palette="colorblind")

g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g4.legend('',frameon=False)

# ax[3][0].set_xticks(['50K','100K'])
ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')
#ax[3][0].loglog(basey=2,basex=2)
# ax[3][0].set_xticks([5, 25, 50, 100])
# ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)
ax[1][1].set(xticklabels=[])  # remove the tick labels
ax[1][1].tick_params(bottom=False)



ax[1][2].set_title('RMAT24-G', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[1][2],hue="method", y="time",palette="colorblind")

g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# ax[3][1].set_xticks(['50K','100K'])
ax[1][2].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][2].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][2].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][2].set(ylabel=None)
ax[1][2].set(xlabel=None)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')

#ax[3][1].loglog(basey=2,basex=2)
# ax[3][1].set_xticks([5, 25, 50, 100])
# ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][2].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][2].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][2].set(ylabel=None)
ax[1][2].set(xlabel=None)
# ax[1][2].set(xticklabels=[])  # remove the tick labels
ax[1][2].tick_params(bottom=False)
g4.legend('',frameon=False)

dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected

ax[1][3].set_title('RMAT25-ER', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[1][3],hue="method", y="time",palette="colorblind")

g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# ax[4][0].set_xticks(['50K','100K'])
ax[1][3].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][3].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][3].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][3].set(ylabel=None)
ax[1][3].set(xlabel=None)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')

#ax[4][0].loglog(basey=2,basex=2)
# ax[4][0].set_xticks([5, 25, 50, 100])
# ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][3].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][3].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][3].set(ylabel=None)
ax[1][3].set(xlabel=None)
ax[1][3].set_xticklabels(('50K', '100K'))
g4.legend('',frameon=False)

dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected

ax[1][4].set_title('RMAT25-G', fontname="Times New Roman", size=8,fontweight="bold",pad=10)

g4=sns.barplot(data=dataselected, x="changes",ax=ax[1][4],hue="method", y="time",palette="colorblind")

g4.legend('',frameon=False)

# ax[4][1].set_xticks(['50K','100K'])
ax[1][4].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][4].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][4].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][4].set(ylabel=None)
ax[1][4].set(xlabel=None)

for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                  size=7, xytext=(0, 8),
                   textcoords='offset points')

#ax[4][1].loglog(basey=2,basex=2)
# ax[4][1].set_xticks([5, 25, 50, 100])
# ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][4].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][4].set(xlabel='Threads', ylabel='Execution Time ratio')
ax[1][4].set(ylabel=None)
ax[1][4].set(xlabel=None)
ax[1][4].set_xticklabels(('50K', '100K'))
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
# plt.xticks(fontsize=8, rotation=90)
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
plt.legend(bbox_to_anchor =(0.1,-0.87), loc='upper center', ncol=2, title='Method')
fig.text(0.04, 0.5, 'Time to update PR (msec)', va='center', rotation='vertical')
fig.text(0.5, 0.04, 'Change size', ha='center')
# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# plt.legend(['Dynamic Update','Dynamic Levelwise'], bbox_to_anchor=(1.05, 1),loc=2, borderaxespad=0.)
fig.savefig("comparisonwithGpuIPDPSworkshop.pdf",dpi=100,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt, ticker as mticker

import matplotlib.ticker
# Creating figure and axis objects using subplots()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.size"] = "10"

plt.rcParams['legend.title_fontsize'] = '10'
fig, ax = plt.subplots(2,2,figsize=[10, 10])
sns.set_style('whitegrid')
fig.subplots_adjust(hspace=0.225, wspace=0.225)
# plt.yscale('log',base=2)
# fig, ax = plt.subplots(figsize=[9, 7])
# ax[0][0].set( yscale="log")
# ax[0][0].semilogy(basey=2)


data=pd.read_csv("scIA3ETC.csv")
dataselected= data[data["graphName"]=="Twitter (WWW)"]
dataselected=dataselected[(dataselected["type"]=="kendall rank coefficient") & (dataselected["ETC"]>3)]
color=['purple','green']


ax[0][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][0].set_title('Twitter (WWW)', fontname="Times New Roman", size=10,fontweight="bold",pad=12)


g1=sns.barplot(data=dataselected, ax=ax[0][0], x="ETC", y="score", hue="changes",  palette="colorblind")

g1.legend('',frameon=False)


ax[0][0].set(xlabel=None)
# ax[0][0].yaxis.label.set_size(30)
ax[0][0].set(ylabel=None)

#ax[0][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[0][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
legend_prop = {'weight':'bold'}
ax[0][0].set(xticklabels=[])  # remove the tick labels
ax[0][0].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[0][0].yaxis.set_major_formatter(formatter)
# plt.xticks([0,2,4,8,16,32,64], ['1', '2', '4','8','16','32','64'])
# plt.legend(prop=legend_prop)
# # plt.savefig("Twitterwww.png",bbox_inches='tight')
# plt.show()

for bar in g1.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g1.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

# ax[0][1].xaxis.set_minor_formatter(mticker.ScalarFormatter())
dataselected= data[data["graphName"]=="Twitter (MPI)"]
dataselected

dataselected=dataselected[(dataselected["type"]=="kendall rank coefficient") & (dataselected["ETC"]>3)]
ax[0][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[0][1].set_title('Twitter (MPI)', fontname="Times New Roman", size=10,fontweight="bold",pad=12)

g2=sns.barplot(data=dataselected, ax=ax[0][1], x="ETC", y="score", hue="changes",  palette="colorblind")
g2.legend('',frameon=False)

ax[0][1].set(xlabel=None)
ax[0][1].set(ylabel=None)
ax[0][1].set(xticklabels=[])
for bar in g2.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g2.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

#
# dataselected= data[data["graphName"]=="PubMed"]
# dataselected
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[0][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# # ax[0][1].set( yscale="log")
#
# # ax[0][1].loglog(basey=2,basex=2)
# ax[0][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# # ax[0][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[0][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# ax[0][1].set(xticklabels=[])  # remove the tick labels
# ax[0][1].tick_params(bottom=False)
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[0][1].yaxis.set_major_formatter(formatter)
#
# ax[1][0].yaxis.label.set_size(20)
# ax[1][0].set_title('PubMed', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
# g3=sns.barplot(data=dataselected, ax=ax[1][0], x="ETC", y="score", hue="changes",  palette="colorblind")
# g3.legend('',frameon=False)
#
# for bar in g3.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g3.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
# # ax[1][0].loglog(basey=2,basex=2)
# ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
# # ax[1][0].set_xticks([1,2,4,8,16,32,64])
# # ax[1][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[1][0].set(ylabel=None)
# ax[1][0].set(ylabel=None)
# ax[1][0].set(xlabel=None)
# ax[1][0].set(xticklabels=[])  # remove the tick labels
# ax[1][0].tick_params(bottom=False)
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[1][0].yaxis.set_major_formatter(formatter)
# dataselected= data[data["graphName"]=="DBpedia links"]
# dataselected
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[1][1].set_title('DBpedia links', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[1][1], x="ETC", y="score", hue="changes",  palette="colorblind")
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
# #ax[1][1].loglog(basey=2,basex=2)
# #ax[1][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[1][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[1][1].set(ylabel=None)
# ax[1][1].set(xlabel=None)
# ax[1][1].set(xticklabels=[])  # remove the tick labels
# ax[1][1].tick_params(bottom=False)
#
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[1][1].yaxis.set_major_formatter(formatter)
# dataselected= data[data["graphName"]=="Wikipedia dynamic (de)"]
# dataselected
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[2][0].set_title('Wikipedia dynamic (de)', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[2][0], x="ETC", y="score", hue="changes",  palette="colorblind")
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# # ax[2][0].loglog(basey=2,basex=2)
# # ax[2][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[2][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[2][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[2][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[2][0].set(ylabel=None)
# ax[2][0].set(xlabel=None)
# ax[2][0].set(xticklabels=[])  # remove the tick labels
# ax[2][0].tick_params(bottom=False)
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[2][0].yaxis.set_major_formatter(formatter)
#
# dataselected= data[data["graphName"]=="Live Journal"]
# dataselected
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[2][1].set_title('Live Journal', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[2][1], x="ETC", y="score", hue="changes",  palette="colorblind")
# g4.legend('',frameon=False)
# #g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Changes', borderaxespad=0.)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
# # ax[2][1].loglog(basey=2,basex=2)
# # ax[2][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[2][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[2][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[2][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[2][1].set(ylabel=None)
# ax[2][1].set(xlabel=None)
# ax[2][1].set(xticklabels=[])  # remove the tick labels
# ax[2][1].tick_params(bottom=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[2][1].yaxis.set_major_formatter(formatter)
#
# dataselected= data[data["graphName"]=="RMAT24-ER"]
# dataselected
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[3][0].set_title('RMAT24-ER', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[3][0], x="ETC", y="score", hue="changes",  palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# g4.legend('',frameon=False)
#
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# #ax[3][0].loglog(basey=2,basex=2)
# # ax[3][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[3][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[3][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[3][0].set(xlabel='Threads', ylabel='Time to update PR')
# ax[3][0].set(ylabel=None)
# ax[3][0].set(xlabel=None)
# ax[3][0].set(xticklabels=[])  # remove the tick labels
# ax[3][0].tick_params(bottom=False)
# # from matplotlib import ticker
# # formatter = ticker.ScalarFormatter(useMathText=True)
# # formatter.set_scientific(True)
# # formatter.set_powerlimits((-1,1))
# # ax[3][0].yaxis.set_major_formatter(formatter)
# dataselected= data[data["graphName"]=="RMAT24-G"]
# dataselected
# dataselected=dataselected[dataselected["type"]=="kendall rank coefficient"]
# ax[3][1].set_title('RMAT24-G', fontname="Times New Roman", size=10,fontweight="bold",pad=12)
#
# g4=sns.barplot(data=dataselected, ax=ax[3][1], x="ETC", y="score", hue="changes",  palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# for bar in g4.patches:
#
#   # Using Matplotlib's annotate function and
#   # passing the coordinates where the annotation shall be done
#   # x-coordinate: bar.get_x() + bar.get_width() / 2
#   # y-coordinate: bar.get_height()
#   # free space to be left to make graph pleasing: (0, 8)
#   # ha and va stand for the horizontal and vertical alignment
#     g4.annotate(format(bar.get_height(), '.2f'),
#                    (bar.get_x() + bar.get_width() / 2,
#                     bar.get_height()), ha='center', va='center',
#                    size=10, xytext=(0, 8),
#                    textcoords='offset points')
#
# # ax[3][1].loglog(basey=2,basex=2)
# # ax[3][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# # ax[3][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
# # ax[3][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
# ax[3][1].set(xlabel='Threads', ylabel='Time to update PR')
# ax[3][1].set(ylabel=None)
# ax[3][1].set(xlabel=None)
# ax[3][1].set(xticklabels=[])  # remove the tick labels
# ax[3][1].tick_params(bottom=False)
# g4.legend('',frameon=False)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[3][1].yaxis.set_major_formatter(formatter)
dataselected= data[data["graphName"]=="RMAT25-ER"]
dataselected
dataselected=dataselected[(dataselected["type"]=="kendall rank coefficient") & (dataselected["ETC"]>3)]
ax[1][0].set_title('RMAT25-ER', fontname="Times New Roman", size=10,fontweight="bold",pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][0], x="ETC", y="score", hue="changes",  palette="colorblind")
g4.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
#ax[4][0].loglog(basey=2,basex=2)
#ax[4][0].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][0].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][0].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][0].set(ylabel=None)
ax[1][0].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[4][0].yaxis.set_major_formatter(formatter)
g4.legend('',frameon=False)
dataselected= data[data["graphName"]=="RMAT25-G"]
dataselected

dataselected=dataselected[(dataselected["type"]=="kendall rank coefficient") & (dataselected["ETC"]>3)]
ax[1][1].set_title('RMAT25-G', fontname="Times New Roman", size=10,fontweight="bold", pad=12)

g4=sns.barplot(data=dataselected, ax=ax[1][1], x="ETC", y="score", hue="changes",  palette="colorblind")
# g4.legend(bbox_to_anchor=(1.05, 1), loc=2,title='Threads', borderaxespad=0.)
g4.legend('',frameon=False)
for bar in g4.patches:

  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    g4.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 10),
                   textcoords='offset points')

#ax[4][1].loglog(basey=2,basex=2)
#ax[4][1].set_xticks(['1M','5M','10M','25M','50M','100M'])
# ax[4][1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax[1][1].yaxis.set_minor_formatter(mticker.ScalarFormatter())
ax[1][1].set(xlabel='Threads', ylabel='Time to update PR')
ax[1][1].set(ylabel=None)
ax[1][1].set(xlabel=None)
# from matplotlib import ticker
# formatter = ticker.ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# ax[4][1].yaxis.set_major_formatter(formatter)

# g4.legend('',frameon=False)
# g4.legend(prop=legend_prop,loc=2)
# plt.legend(bbox_to_anchor=(1.05, 1), loc=0, borderaxespad=0.)
# plt.xticks(fontsize=8, rotation=90)
plt.legend(bbox_to_anchor =(0.45,-0.17), loc='upper center', ncol=2, title='Changes')
# plt.semilogy(basey=2)
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
fig.text(0.04, 0.5, 'Kendall Rank Correlation Coefficient', va='center', rotation='vertical')
fig.text(0.5, 0.04, 'Early Termination Condition', ha='center')
# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))


fig.savefig("sharedmemoryetckendallIPDPSworkshop.pdf",dpi=100,bbox_inches='tight')
